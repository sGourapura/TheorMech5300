# %% [markdown]
# # Gravitational Orbits
#
# We solve the Two-Body Orbit first, then the Three-Body Orbit.

# %% [markdown]
# ## Two-Body Orbit
#
# We will solve the Two-Body using the Lagrangian method. It is easier to code this using cartesian coordinates:
#
# $T = \frac{1}{2} m_1 (\dot{x_1}^2 +\dot{y_1}^2)+\frac{1}{2} m_2 ((\dot{x_1}+\dot{x_2})^2 +(\dot{y_1}+\dot{y_2})^2)$
#
# $U = \frac{-G m_1 m_2}{\sqrt{(x_2-x_1)^2 +(y_2-y_1)^2}}$
#
# $L = T - U$
#
# Using the Euler-Lagrange equations, we get four, second-order, ordinary, coupled differential equations. I solve these for \{$\ddot x_1, \ddot y_1, \ddot x_2, \ddot y_2$\} in my Mathematica notebook DoubleOrbitCalc.nb using Mathematica's "Solve" function. The solution to these are implemented in the DoubleOrbit class for y_dot[4:8].

# %%
# %matplotlib inline

import numpy as np
from scipy.integrate import odeint, solve_ivp
import matplotlib.pyplot as plt

# The dpi (dots-per-inch) setting will affect the resolution and how large
#  the plots appear on screen and printed.  So you may want/need to adjust 
#  the figsize when creating the figure.
plt.rcParams['figure.dpi'] = 100.    # this is the default for notebook

# Change the common font size (smaller when higher dpi)
font_size = 10
plt.rcParams.update({'font.size': font_size})

# Import the widgets we will use (add more as needed!) 
import ipywidgets as widgets
from ipywidgets import HBox, VBox, Layout, Tab, Label, Checkbox
from ipywidgets import FloatSlider, IntSlider, Play, Dropdown, HTMLMath 

from IPython.display import display
from time import sleep

# %%
# Get our orbit classes out of the way first

class DoubleOrbit():
    """
    DoubleOrbit class implements the parameters and differential equation 
    for two-body gravitational motion using the notation above.
     
    Parameters
    ----------
    m1 : float
        first bob's mass 
    m2 : float
        second bob's mass
    G  : float
        value of gravitational constant 

    Methods
    -------
    dy_dt(t, y)
        Returns the right side of the differential equation in vector y, 
        given time t and the corresponding value of y.
    """
    def __init__(self, m1=1., m2=1., G=1.):
        self.m1=m1
        self.m2=m2
        self.G=G
    
    def dy_dt(self, t, y):
        """
        This function returns the right-hand side of the diffeq
        
        Parameters
        ----------
        t : float
            time 
        y : float
            A 4-component vector with 
            y[0] = x_1(t)    = x1
            y[1] = y_1(t)    = y1
            y[2] = x_2(t)    = x2
            y[3] = y_2(t)    = y2
            y[4] = dx_1/dt(t)= u1
            y[5] = dy_1/dt(t)= v1
            y[6] = dx_2/dt(t)= u2
            y[7] = dy_2/dt(t)= v2
            
        Returns
        -------
        y_dot: float
            A 4-component vector with 
            y_dot[0] = dx_1/dt(t)= u1
            y_dot[1] = dy_1/dt(t)= v1
            y_dot[2] = dx_2/dt(t)= u2
            y_dot[3] = dy_2/dt(t)= v2  
            y_dot[4] = d^2 x_1/dt^2(t)
            y_dot[5] = d^2 y_1/dt^2(t)
            y_dot[6] = d^2 x_2/dt^2(t)
            y_dot[7] = d^2 y_2/dt^2(t) 
        
        """
        y_dot = np.zeros((8))
        x1, y1, x2, y2, u1, v1, u2, v2 = y
        
        G = self.G
        m1 = self.m1
        m2 = self.m2

        x21 = x2-x1
        y21 = y2-y1
        
        denom = ((x21**2)+(y21**2))**(3./2.)
        
        # Do dphi_1/dt and dphi_2/dt first:
        y_dot[0:4] = y[4:8]
        
        # Now do d^2 x_{1,2}/dt^2(t) 
        y_dot[4]= G*m2*x21/denom
        y_dot[6]= -G*m1*x21/denom            
            
        # Finally do d^2 y_{1,2}/dt^2(t) 
        y_dot[5]= G*m2*y21/denom
        y_dot[7]= -G*m1*y21/denom
        
        return y_dot
    
    
    def solve_ode(self, t_pts, y, 
                  abserr=1.0e-8, relerr=1.0e-6):
        """
        Solve the ODE given initial conditions.
        For now use odeint, but we have the option to switch.
        Specify smaller abserr and relerr to get more precision.
        """
        solution = solve_ivp(self.dy_dt, (t_pts[0], t_pts[-1]), 
                             y, t_eval=t_pts, 
                             atol=abserr, rtol=relerr)
        return solution.y
    
    def solve_ode_Leapfrog(self, t_pts, y_0):
        """
        Solve the ODE given initial conditions with the Leapfrog method.
        """
        # Grab useful data from t_pts
        delta_t = t_pts[1] - t_pts[0]
        num_t_pts = len(t_pts)
        # Hold x1, y1, x2, y2 = q
        q = np.zeros((4, num_t_pts))
        # Hold x1_dot, y1_dot, x2_dot, y2_dot = q_dot
        q_dot = np.zeros((4, num_t_pts))
        # Hold x1_dot_half, y1_dot_half, x2_dot_half, y2_dot_half=q_dot_half
        q_dot_half = np.zeros((4, num_t_pts)) 
        
        # initial conditions
        q[:,0] = y_0[0:4]
        q_dot[:,0] = y_0[4:8]
        
        # step through the differential equation
        for i in np.arange(num_t_pts - 1):
            t = t_pts[i]
            # Initialize the y-vec to find derivatives
            y = np.zeros((8))
            y[0:4] = q[:,i]
            y[4:8] = q_dot[:,i]
            # Calculate q_dot_half
            q_dot_half[:,i] = q_dot[:,i] + self.dy_dt(t, y)[4:8]*delta_t/2.
            # Calculate q(i+1)
            q[:,i+1] = q[:,i] + q_dot_half[:,i] * delta_t
            # Fill the y-vec again to find derivatives with q[i+1]
            y[0:4] = q[:,i+1]
            y[4:8] = q_dot[:,i]
            # Calculate q_dot
            q_dot[:,i+1] = q_dot_half[:,i] + self.dy_dt(t, y)[4:8] \
                         * delta_t/2.
        # Create return vector    
        y_ret = np.zeros((8, num_t_pts))
        y_ret[:4,:] = q
        y_ret[4:,:] = q_dot    
        return y_ret  
    
class DoubleOrbitSimple():
    """
    DoubleOrbitSimple class implements the parameters and differential equation 
    for two-body gravitational motion assuming m1 >> m2, using the notation below.
     
    Parameters
    ----------
    m1 : float
        heavy bob's mass 
    G  : float
        value of gravitational constant 

    Methods
    -------
    dy_dt(t, y)
        Returns the right side of the differential equation in vector y, 
        given time t and the corresponding value of y.
    """
    def __init__(self, m1=1., G=1.):
        self.m1=m1
        self.G=G
    
    def dy_dt(self, t, y):
        """
        This function returns the right-hand side of the diffeq
        
        Parameters
        ----------
        t : float
            time 
        y : float
            A 4-component vector with 
            y[0] = x(t)    = x2
            y[1] = y(t)    = y2
            y[2] = dx/dt(t)= x2_dot
            y[3] = dy/dt(t)= y2_dot
            
        Returns
        -------
        y_dot: float
            A 4-component vector with 
            y_dot[1] = dx/dt(t)     = x2_dot
            y_dot[2] = dy/dt(t)     = y2_dot
            y_dot[3] = d^2 x/dt^2(t)
            y_dot[4] = d^2 y/dt^2(t) 
        
        """
        y_dot = np.zeros((4))
        x2, y2, x2_dot, y2_dot = y
        
        G = self.G
        M = self.m1
        denom = (x2**2 + y2**2)**(3./2.)
        # Do dx/dt, dy/dt first:
        y_dot[0:2] = y[2:4]
        
        # Now do d^2 x/dt^2(t) 
        y_dot[2]= -G * M * x2 / denom        
            
        # Finally do d^2 y/dt^2(t) 
        y_dot[3]= -G * M * y2 / denom
        
        return y_dot
    
    def solve_ode(self, t_pts, y_0, 
                  abserr=1.0e-8, relerr=1.0e-6):
        """
        Solve the ODE given initial conditions.
        Takes ICs for both obj 1 and 2, but only uses those for obj 2
        """
        x1_0, y1_0, x2_0, y2_0, x1_dot_0, y1_dot_0, x2_dot_0, \
            y2_dot_0 = y_0
        y = np.array([x2_0, y2_0, x2_dot_0, y2_dot_0])
        solution = solve_ivp(self.dy_dt, (t_pts[0], t_pts[-1]), 
                             y, t_eval=t_pts, 
                             atol=abserr, rtol=relerr)
        
        return solution.y
    

class TripleOrbit():
    """
    TripleOrbit class implements the parameters and differential equation for 
     three-body gravitational motion using the notation above.
     
    Parameters
    ----------
    m1 : float
        first bob's mass 
    m2 : float
        second bob's mass
    m3 : float
        third bob's mass
    G  : float
        value of gravitational constant 

    Methods
    -------
    dy_dt(t, y)
        Returns the right side of the differential equation in vector y, 
        given time t and the corresponding value of y.
    """
    def __init__(self, m1=1., m2=1., m3=1., G=1.):
        self.m1=m1
        self.m2=m2
        self.m3=m3
        self.G=G
    
    def dy_dt(self, t, y):
        """
        This function returns the right-hand side of the diffeq
        
        Parameters
        ----------
        t : float
            time 
        y : float
            A 4-component vector with 
            y[0] = x_1(t) = x1
            y[1] = y_1(t) = y1
            y[2] = x_2(t) = x2
            y[3] = y_2(t) = y2
            y[4] = x_3(t) = x3
            y[5] = y_3(t) = y3
            
            y[6] = dx_1/dt(t)
            y[7] = dy_1/dt(t)
            y[8] = dx_2/dt(t)
            y[9] = dy_2/dt(t)
            y[10] = dx_3/dt(t)
            y[11] = dy_3/dt(t)
            
        Returns
        -------
        y_dot: float
            A 4-component vector with 
            y_dot[0] = dx_1/dt(t) = y[6]
            y_dot[1] = dy_1/dt(t) = y[7]
            y_dot[2] = dx_2/dt(t) = y[8]
            y_dot[3] = dy_2/dt(t) = y[9]
            y_dot[4] = dx_3/dt(t) = y[10]
            y_dot[5] = dy_3/dt(t) = y[11]            
            
            y_dot[6] = d^2 x_1/dt^2(t)
            y_dot[7] = d^2 y_1/dt^2(t)
            y_dot[8] = d^2 x_2/dt^2(t)
            y_dot[9] = d^2 y_2/dt^2(t) 
            y_dot[10] = d^2 x_3/dt^2(t)
            y_dot[11] = d^2 y_3/dt^2(t)        
        """
        # Initialize return vector
        y_dot = np.zeros((12))
        # Define position vals 
        x1, y1, x2, y2, x3, y3 = y[0:6]
        # Grab constants
        G = self.G
        m1 = self.m1
        m2 = self.m2
        m3 = self.m3
        # Define useful calculated values
        x21, y21 = x2 - x1, y2 - y1
        x32, y32 = x3 - x2, y3 - y2
        x31, y31 = x3 - x1, y3 - y1
        denom21 = ((x21**2)+(y21**2))**(3./2.)
        denom32 = ((x32**2)+(y32**2))**(3./2.)
        denom31 = ((x31**2)+(y31**2))**(3./2.)
        
        # Do dx_i/dt first:
        y_dot[0:6] = y[6:12]
        
        # Now do d^2 x_i/dt^2(t) 
        y_dot[6]= G*(m2*x21/denom21 + m3*x31/denom31)
        y_dot[8]= G*(-m1*x21/denom21 + m3*x32/denom32)            
        y_dot[10]= G*(-m2*x31/denom31 - m3*x32/denom32)
        
        # Finally do d^2 y_i/dt^2(t) 
        y_dot[7]= G*(m2*y21/denom21 + m3*y31/denom31)
        y_dot[9]= G*(-m1*y21/denom21 + m3*y32/denom32)
        y_dot[11]= G*(-m2*y31/denom31 - m3*y32/denom32)
        return y_dot       
        
    def solve_ode(self, t_pts, y, 
                  abserr=1.0e-8, relerr=1.0e-6):
        """
        Solve the ODE given initial conditions.
        For now use odeint, but we have the option to switch.
        Specify smaller abserr and relerr to get more precision.
        """
        solution = solve_ivp(self.dy_dt, (t_pts[0], t_pts[-1]), 
                             y, t_eval=t_pts, 
                             atol=abserr, rtol=relerr)
        return solution.y
    
    def solve_ode_Leapfrog(self, t_pts, y_0):
        """
        Solve the ODE given initial conditions with the Leapfrog method.
        """
        delta_t = t_pts[1] - t_pts[0]
        
        # initialize the arrays for r, rdot, r_dot_half, phi with zeros
        num_t_pts = len(t_pts)
        # Hold x1, y1, x2, y2, x3, y3 = q
        q = np.zeros((6, num_t_pts))
        # Hold x1_dot, y1_dot, x2_dot, y2_dot, x3_dot, y3_dot = q_dot
        q_dot = np.zeros((6, num_t_pts))
        # Hold x1_dot_half, y1_dot_half, x2_dot_half, y2_dot_half, 
        # x3_dot_half, y3_dot_half = q_dot_half
        q_dot_half = np.zeros((6, num_t_pts)) 
        
        # initial conditions
        q[:,0] = y_0[0:6]
        q_dot[:,0] = y_0[6:12]
        
        # step through the differential equation
        for i in np.arange(num_t_pts - 1):
            t = t_pts[i]
            # Initialize the y-vec to find derivatives
            y = np.zeros((12))
            y[0:6] = q[:,i]
            y[6:12] = q_dot[:,i]
            # Calculate q_dot_half
            q_dot_half[:,i] = q_dot[:,i] + self.dy_dt(t, y)[6:12]*delta_t/2.
            # Calculate q(i+1)
            q[:,i+1] = q[:,i] + q_dot_half[:,i] * delta_t
            # Fill the y-vec again to find derivatives with q[i+1]
            y[0:6] = q[:,i+1]
            y[6:12] = q_dot[:,i]
            # Calculate q_dot
            q_dot[:,i+1] = q_dot_half[:,i] + self.dy_dt(t, y)[6:12] \
                         * delta_t/2.
        # Create return vector    
        y_ret = np.zeros((12, num_t_pts))
        y_ret[:6,:] = q
        y_ret[6:,:] = q_dot    
        return y_ret

# %%
def plot_y_vs_x(x, y, axis_labels=None, label=None, title=None, 
                color=None, linestyle=None, semilogy=False, loglog=False,
                polar=False, ax=None):
    """
    Generic plotting function: return a figure axis with a plot of y vs. x,
    with line color and style, title, axis labels, and line label
    """
    if ax is None:        # if the axis object doesn't exist, make one
        ax = plt.gca()

    if (semilogy):
        line, = ax.semilogy(x, y, label=label, 
                            color=color, linestyle=linestyle)
    elif (loglog):
        line, = ax.loglog(x, y, label=label, 
                          color=color, linestyle=linestyle)
    else:
        line, = ax.plot(x, y, label=label, 
                    color=color, linestyle=linestyle)

    if label is not None:    # if a label if passed, show the legend
        ax.legend()
    if title is not None:    # set a title if one if passed
        ax.set_title(title)
    if axis_labels is not None:  # set x-axis and y-axis labels if passed  
        ax.set_xlabel(axis_labels[0])
        ax.set_ylabel(axis_labels[1])

    return ax, line

def start_stop_indices(t_pts, plot_start, plot_stop):
    start_index = (np.fabs(t_pts-plot_start)).argmin()  # index in t_pts array 
    stop_index = (np.fabs(t_pts-plot_stop)).argmin()  # index in t_pts array 
    return start_index, stop_index

# Widgets for the pendulum parameters (all use FloatSlider, so made function)
def float_widget(value, min, max, step, description, format):
    """Makes a FloatSlider with the passed parameters and continuous_update
       set to False."""
    slider_border = Layout(border='solid 1.0px')
    return FloatSlider(value=value,min=min,max=max,step=step,disabled=False,
                       description=description,continuous_update=False,
                       orientation='horizontal',layout=slider_border,
                       readout=True,readout_format=format)

def StationaryIC2(orbit, sep, Ltot):
    """For Double Orbit
    Finds ICs such that they start on the x-axis with seperation sep
    and total angular momentum Ltot. Done using momentum conservation
    Grab the masses"""
    m1 = orbit.m1
    m2 = orbit.m2
    
    # Calculate x1_0 and x2_0. Note x1_0 always negative
    x1_0 = -m2 * sep / (m1 + m2)
    x2_0 = m1 * sep / (m1 + m2)
    
    # Calculate y1_dot_0 and y2_dot_0. Note y1_dot_0 always negative
    # This calculation was done seperately by forcing p_x_tot=p_y_tot=0
    y1_dot_0 = Ltot/(m1*(x1_0-x2_0))
    y2_dot_0 = -Ltot/(m2*(x1_0-x2_0))
    
    # The rest of the I.C.s are held to zero
    IC = np.zeros((8))
    IC[0], IC[2] = x1_0, x2_0
    IC[5], IC[7] = y1_dot_0, y2_dot_0
    
    return IC

def CalcEnergy2(orbit, y):
    """ For Double Orbit
    Calculate the energy of a set of ICs using y = y_0
    Or calculate an array of energies for y (size: 8 x num_t_pts)"""
    
    # Grab the masses and G
    m1 = orbit.m1
    m2 = orbit.m2   
    G = orbit.G
    
    # Grab the elements of y. These are either scalars or arrays
    x1, y1, x2, y2,x1_dot, y1_dot, x2_dot, y2_dot = y
    
    # Calculate Total Energy. Since we are using cartesian coords, E=T+U
    T = 0.5*m1*(x1_dot**2 + y1_dot**2)+0.5*m2*(x2_dot**2 + y2_dot**2)
    U = -G*m1*m2 / np.sqrt( (x2-x1)**2+(y2-y1)**2 )
    
    return T + U

def CheckEscaped2(orbit, y_0):
    """For Double Orbit
    Check if the orbit is closed or if the object escapes"""
    Energy = CalcEnergy2(orbit, y_0)
    
    if Energy > 0:
        print(rf'The orbit has escaped! Total Energy > 0')
        print(rf'Total Energy is: {Energy:.3f}, ')
    else:
        print(rf'The orbit is contained. Total Energy < 0')
        print(rf'Total Energy is: {Energy:.3f}, ')


# Labels for individual plot axes
x_vs_y_labels = (r'$x$', r'$y$')
deltax_vs_deltay = (r'$\dot x$', r'$\dot y$')
E_vs_t_labels = ('Time', 'Energy')

# %%
            
def Plot_DoubleOrbit(m_1=5., m_2=5., G_val=1.,
                    seperation=2., Ltot=10.,
                    delta_t=0.001, t_end=50):

    # Instantiate an orbit 
    do1 = DoubleOrbit(m1=m_1, m2 = m_2, G=G_val)
    # The simple orbit is what we expect for m1 >> m2
    doSimp = DoubleOrbitSimple(m1=m_1, G=G_val)
    
    # Create the time points
    t_start = 0.
    t_pts = np.arange(t_start, t_end+delta_t, delta_t)  
    # Calculate Initial Conditions to force total momentum = 0
    IC = StationaryIC2(orbit=do1, sep=seperation, Ltot=Ltot)
    # Print order is:
    # x1_0, y1_0, x2_0, y2_0, x1_dot_0, y1_dot_0, x2_dot_0, y2_dot_0
    # print(IC)

    # Can use IC or type by hand
    x1_0, y1_0 = IC[0:2] #-1., 0.
    x2_0, y2_0 = IC[2:4] #1., 0.
    x1_dot_0, y1_dot_0 = IC[4:6] #0., -1.5
    x2_dot_0, y2_dot_0 = IC[6:8] #0., 1.5
    y_0 =[x1_0, y1_0, x2_0, y2_0, x1_dot_0, y1_dot_0, x2_dot_0, y2_dot_0]
    
    # Check if the orbit has escaped and print the result
    CheckEscaped2(do1, y_0)
    
    # Calculate the solution using solve_ivp
    y_ivp = do1.solve_ode(t_pts, y_0)
    x1, y1, x2, y2, x1_dot, y1_dot, x2_dot, y2_dot =y_ivp
    # Calculate the solution using Leapfrog
    y_Leap = do1.solve_ode_Leapfrog(t_pts, y_0)
    x1_L, y1_L, x2_L, y2_L, x1_dot_L, y1_dot_L, x2_dot_L, y2_dot_L = y_Leap
    # Calculate the solution using simple double orbit solve_ivp
    x2_S, y2_S, x2_dot_S, y2_dot_S = doSimp.solve_ode(t_pts, y_0)
    
    # Calculate energies for the two methods
    E_ivp = CalcEnergy2(do1, y_ivp)
    E_Leap = CalcEnergy2(do1, y_Leap)
    
    # start the plot!
    fig = plt.figure(figsize=(15,15))
    
    overall_title = 'Double Orbit:  ' + \
                    rf' $m_1 = {m_1:.2f},$' + \
                    rf' $m_2 = {m_2:.2f},$' + \
                    rf' $G = {G_val:.2f},$' + \
                    rf' $Sep = {seperation:.2f},$' + \
                    rf' $Ltot = {Ltot:.2f},$' + '\n' + \
                    rf' $x_1(0) = {x1_0:.2f},$' + \
                    rf' $y_1(0) = {y1_0:.2f},$' + \
                    rf' $\dot x_1(0) = {x1_dot_0:.2f},$'+ \
                    rf' $\dot y_1(0) = {y1_dot_0:.2f},$' + '\n' \
                    rf' $x_2(0) = {x2_0:.2f},$' + \
                    rf' $y_2(0) = {y2_0:.2f},$' + \
                    rf' $\dot x_2(0) = {x2_dot_0:.2f},$' + \
                    rf' $\dot y_2(0) = {y2_dot_0:.2f},$'
    fig.suptitle(overall_title, va='baseline')
    
    # first plot position: solve_ivp   
    ax_a = fig.add_subplot(3,2,1)
    # Add an 'x' at the CM of two objects (if using CalcStationaryIC)
    ax_a.plot([0], [0], 'x', c='orange')
    
    start, stop = start_stop_indices(t_pts, t_start, t_end)   
    plot_y_vs_x(x1[start : stop], y1[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_a)  
    plot_y_vs_x(x2[start : stop], y2[start : stop], 
                axis_labels=x_vs_y_labels, 
                color='red',
                label="Object 2", 
                title=rf'solve_ivp x vs y:$0 \leq t \leq {t_end:.1f}$', 
                ax=ax_a)  
    
    # second plot: solve_ivp  
    ax_b = fig.add_subplot(3,2,2)                  
    ax_b.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1_dot[start : stop], y1_dot[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_b)  
    plot_y_vs_x(x2_dot[start : stop], y2_dot[start : stop], 
                axis_labels=deltax_vs_deltay, 
                color='red',
                label="Object 2", 
                title=rf'solve_ivp xdot vs ydot:$0 \leq t \leq {t_end:.1f}$', 
                ax=ax_b)  
    
    
    # first plot position: Leapfrog   
    ax_a = fig.add_subplot(3,2,3)                  
    ax_a.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1_L[start : stop], y1_L[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_a)  
    plot_y_vs_x(x2_L[start : stop], y2_L[start : stop], 
                axis_labels=x_vs_y_labels, 
                color='red',
                label="Object 2", 
                title=rf'Leapfrog x vs y: $0 \leq t \leq {t_end:.1f}$', 
                ax=ax_a)  
    
    # second plot state space: Leapfrog   
    ax_b = fig.add_subplot(3,2,4)                  
    ax_b.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1_dot_L[start : stop], y1_dot_L[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_b)  
    plot_y_vs_x(x2_dot_L[start : stop], y2_dot_L[start : stop], 
                axis_labels=deltax_vs_deltay, 
                color='red',
                label="Object 2", 
                title=rf'Leapfrog xdot vs ydot: $0 \leq t \leq {t_end:.1f}$', 
                ax=ax_b)
    
    # first plot position: Simple Orbit   
    ax_a = fig.add_subplot(3,2,5)                  
    ax_a.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x([0], [0], 
                color='blue',
                label="Object 1",
                ax=ax_a)  
    plot_y_vs_x(x2_S[start : stop], y2_S[start : stop], 
                axis_labels=x_vs_y_labels, 
                color='red',
                label="Object 2", 
                title=rf'Simple Orbit (assuming m1 >> m2) x vs y: $0 \leq t \leq {t_end:.1f}$', 
                ax=ax_a)  
    
    # second plot Energy vs. Time:  
    ax_b = fig.add_subplot(3,2,6)                  
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(t_pts[start : stop], E_ivp[start : stop],
                color='blue',
                label="Solver: solve_ivp",
                semilogy=False,
                ax=ax_b)  
    plot_y_vs_x(t_pts[start : stop], E_Leap[start : stop], 
                axis_labels=E_vs_t_labels, 
                color='red',
                label="Solver: Leapfrog", 
                title=rf'Comparing solve_ivp and Leapfrog: $0 \leq t \leq {t_end:.1f}$',
                semilogy=False,
                ax=ax_b)
    
    fig.tight_layout()
    fig.savefig('DoubleOrbit.png', bbox_inches='tight')  # always bbox_inches='tight'
    return fig

# Create the sliders we are interested in
m_1_w = float_widget(value=5., min=0., max=100., step=0.01,
                         description=r'$m_1$:', format='.2f')
m_2_w = float_widget(value=5., min=0., max=100., step=0.01,
                         description=r'$m_2$:', format='.2f')
G_val_w = float_widget(value=1., min=0., max=10., step=0.1,
                         description=r'$G$:', format='.1f')
seperation_w = float_widget(value=2., min=0., max=20, step=0.1,
                         description=r'Seperation:', format='.1f')
Ltot_w = float_widget(value=10., min=-50., max=50., step=0.1,
                         description=r'$L_{{tot}}$:', format='.1f')
delta_t_w = float_widget(value=0.001, min=0.00001, max=0.1, step=0.0001,
                         description=r'$\Delta t$:', format='.5f')
t_end_w = float_widget(value=50., min=0., max=100., step=1.,
                         description=r'$T_f$:', format='.0f')

# Set up the interactive_output widget 
plot_out = widgets.interactive_output(Plot_DoubleOrbit,
                    dict( 
                    m_1=m_1_w,
                    m_2=m_2_w,
                    G_val=G_val_w,
                    seperation=seperation_w,
                    Ltot=Ltot_w,
                    delta_t=delta_t_w,
                    t_end=t_end_w
                    )
                )
# We want two 
hbox1 = HBox([m_1_w, m_2_w, G_val_w])
hbox2 = HBox([seperation_w, Ltot_w])
hbox3 = HBox([delta_t_w, t_end_w])

tab_height = '70px'  # Fixed minimum height for all tabs. Specify another way?
tab0 = VBox([hbox1, hbox2, hbox3], layout=Layout(min_height=tab_height))
vbox = VBox([tab0, plot_out])

display(vbox)

# %% [markdown]
# ### Energy Correlation with Orbit
#
# As we learned in class, if $E_{tot}>0$, the object is unbound. In this case, both objects go on hyperbolic orbits and never see each other again. To check this, I implemented a quick function that calculates $E_{tot}$ and prints it above the plots. It simply calculates T + U for the $t=0$ instant.
#
# ### Leapfrog vs. solve_ivp
#
# Above we have plotted the solutions created by solve_ivp and those created by the Leapfrog algorithm. Both do a great job, as long as the two bodies don't get too close. They can get close due to either too low $L_{tot}$, too high of masses, or too high $G$. When this happens, the Leapfrog method starts falling apart. However, it's abilities can be bosted if we decrease $\Delta t$ further, although this leads to long computation time. When the objects get far too close, the solve_ivp method also breaks down. Where Leapfrog shines in it's conservation of energy. In the Energy vs. Time plot, we can see that both solvers must start at the same energy (at -7.5 for my ICs). As time passes, the solve_ivp solver starts to lose energy linearly with time, whereas the Leapfrog method preserves energy over many repetitions.
#
#
#
# ### If $m_1 >> m_2$:
#
# Problem reduces to the orbits considered in class if m1 >> m2 and you are in the rest frame. We show this by first forcing all plots above to be in CM rest frame and starting both objects on the x-axis. We force CM frame by choosing seperation distance and total angular momentum as our initial conditions, forcing $\dot x_1, \dot x_2, y_1, y_2=0$, and calculating $\dot y_1, \dot y_2$ using the conservation of momentum equations. We are now always in the rest frame, for any choice on the widgets.
#
# Second, we can solve the Lagrangian for the assumption $m_1 >> m_2$. This assumption implies $x_1, y_1, \dot x_1, \dot y_1 = 0$. We therefore get:
#
# $L =\frac{1}{2} m_2 (\dot{x_2}^2 +\dot{y_2}^2)+ \frac{-G m_1 m_2}{\sqrt{x_2^2 +y_2^2}}$
#
# Using the Euler-Lagrange equations, we get two, second-order, ordinary, coupled differential equations. I solve these for \{$\ddot x_2, \ddot y_2$\} in my Mathematica notebook DoubleOrbitCalc.nb using Mathematica's "Solve" function (at the bottom). The solution to these are implemented in the DoubleOrbitSimple class for y_dot[2:4].
#
# The third pair of orbits above shows the solution to this class. The first object is stuck on the yellow cross due to the asssumptions made earlier, and the second object orbits around in elliptical fashion. If we choose $m_1 = 80$, $m_2 = 5$, we can see that the orbits for object 2 are virtually identical to the unapproximated solutions. However, for $m_1 \approx m_2$, the orbits are clearly very different. This shows that the problem does reduce down to the elliptical orbits we considered in class if $m_1$ is very heavy and we are in the rest frame

# %% [markdown]
# ## Three-Body Orbit
#
# We will solve the Three-Body problem again using the Lagrangian method. In cartesian coordinates:
#
# $T = \frac{1}{2} m_1 (\dot{x_1}^2 +\dot{y_1}^2)
#     +\frac{1}{2} m_2 ((\dot{x_1}+\dot{x_2})^2 +(\dot{y_1}+\dot{y_2})^2)
#     +\frac{1}{2} m_3 ((\dot{x_1}+\dot{x_2}+\dot{x_3})^2 +(\dot{y_1}+\dot{y_2}+\dot{y_3})^2)$
#
# $U = \frac{-G m_1 m_2}{\sqrt{(x_2-x_1)^2 +(y_2-y_1)^2}}
#     +\frac{-G m_2 m_3}{\sqrt{(x_3-x_2)^2 +(y_3-y_2)^2}}
#     +\frac{-G m_3 m_1}{\sqrt{(x_1-x_3)^2 +(y_1-y_3)^2}}$
#
# $L = T - U$
#
# Using the Euler-Lagrange equations, we get six, second-order, ordinary, coupled differential equations. I solve these for \{$\ddot x_1, \ddot y_1, \ddot x_2, \ddot y_2, \ddot x_3, \ddot y_3$\} in my Mathematica notebook TripleOrbitCalc.nb using Mathematica's "Solve" function. The solution to these are implemented in the TripleOrbit class for y_dot[6:12] above.

# %%
def StationaryIC3(orbit, x1_dot_0, y1_dot_0, x2_dot_0, y2_dot_0):
    """Calculates the velocity of obj 3 to keep system momentum = 0"""
    m1 = orbit.m1
    m2 = orbit.m2
    m3 = orbit.m3
    x3_dot_0 = -(m1/m3)*x1_dot_0 - (m2/m3)*x2_dot_0
    y3_dot_0 = -(m1/m3)*y1_dot_0 - (m2/m3)*y2_dot_0
    return x3_dot_0, y3_dot_0


def CheckEscaped3(orbit, y_0):
    """For Double Orbit
    Check if the orbit is closed or if the object escapes"""
    
    # Grab the masses and G
    m1 = orbit.m1
    m2 = orbit.m2
    m3 = orbit.m3
    G = orbit.G
    # Grab the ICs
    x1, y1, x2, y2, x3, y3 = y_0[0:6]
    x1_dot, y1_dot, x2_dot, y2_dot, x3_dot, y3_dot = y_0[6:12]
    
    # Total Energy must be >0. Since we are using cartesian coords:
    # E= T + U = T1 + T2 + T3 + U21 + U32 + U13
    T1 = 0.5*m1*(x1_dot**2 + y1_dot**2)
    T2 = 0.5*m2*(x2_dot**2 + y2_dot**2)
    T3 = 0.5*m2*(x3_dot**2 + y3_dot**2)
    U21 = -G*m1*m2 / np.sqrt( (x2-x1)**2+(y2-y1)**2 )
    U32 = -G*m2*m3 / np.sqrt( (x3-x2)**2+(y3-y2)**2 )
    U13 = -G*m3*m1 / np.sqrt( (x1-x3)**2+(y1-y3)**2 )
    
    Etot = T1 + T2 + T3 + U21 + U32 + U13
    
    if Etot > 0:
        print('The orbit has escaped! Total Energy > 0')
        print(rf'Total Energy is: {Etot:.3f}, ')
    else:
        # We have to put "may be" because as I learned, the first two
        # objects may inject their energy into the third, causing 
        # two contained and one free
        print('The orbit may be contained. Total Energy < 0')
        print(rf'Total Energy is: {Etot:.3f}, ')
    
def Plot_TripleOrbit(m_1=5.,                 m_2=5., 
                    m_3=5.,                  G_val=2.,
                    x1_0=0.,                 y1_0=5.,
                    x2_0=-5.*np.sqrt(3.)/2., y2_0=-5./2,
                    x3_0= 5.*np.sqrt(3.)/2., y3_0=-5./2,
                    x1_dot_0=-1,             y1_dot_0=0.,
                    x2_dot_0=0.5,            y2_dot_0=-np.sqrt(3.)/2.,
                    delta_t=0.001,           t_end=100):
    
    # Create the time pts
    t_start = 0.    
    t_pts = np.arange(t_start, t_end+delta_t, delta_t)  

    # Instantiate a pendulum 
    to1 = TripleOrbit(m1 = m_1, m2 = m_2, m3 = m_3, G = G_val)
        
    # Calculate Initial Conditions for q3_dot to keep total momentum = 0 
    x3_dot_0, y3_dot_0 = StationaryIC3(to1, x1_dot_0, y1_dot_0, \
                                              x2_dot_0, y2_dot_0)
    
    # Setup IC for Diff. Eq. Solvers
    y_0 =[x1_0, y1_0, x2_0, y2_0, x3_0, y3_0, x1_dot_0, y1_dot_0, x2_dot_0, \
            y2_dot_0, x3_dot_0, y3_dot_0]
    
    # Check if the orbit has escaped and print the result
    CheckEscaped3(to1, y_0)
    
    # Solve differential equations and store in variables using:
    # solve_ivp
    x1, y1, x2, y2, x3, y3, x1_dot, y1_dot, x2_dot, y2_dot, x3_dot, y3_dot \
        = to1.solve_ode(t_pts, y_0)
    # Leapfrog
    x1_2, y1_2, x2_2, y2_2, x3_2, y3_2, x1_dot_2, y1_dot_2, x2_dot_2,  \
        y2_dot_2, x3_dot_2, y3_dot_2 = to1.solve_ode_Leapfrog(t_pts, y_0)
    
    # start the plot!
    fig = plt.figure(figsize=(15,15))
    
    overall_title_general = 'Double Orbit:  ' + \
                    rf' $m_1 = {m_1:.2f},$' + \
                    rf' $m_2 = {m_2:.2f},$' + \
                    rf' $m_3 = {m_3:.2f},$' + \
                    rf' $G = {G_val:.2f},$' + \
                    rf' $x_1(0) = {x1_0:.2f},$' + \
                    rf' $y_1(0) = {y1_0:.2f},$' + \
                    rf' $\dot x_1(0) = {x1_dot_0:.2f},$'+ \
                    rf' $\dot y_1(0) = {y1_dot_0:.2f},$' + '\n' \
                    rf' $x_2(0) = {x2_0:.2f},$' + \
                    rf' $y_2(0) = {y2_0:.2f},$' + \
                    rf' $\dot x_2(0) = {x2_dot_0:.2f},$' + \
                    rf' $\dot y_2(0) = {y2_dot_0:.2f},$' + \
                    rf' $x_3(0) = {x3_0:.2f},$' + \
                    rf' $y_3(0) = {y3_0:.2f},$' + \
                    rf' $\dot x_3(0) = {x3_dot_0:.2f},$'+ \
                    rf' $\dot y_3(0) = {y3_dot_0:.2f},$'+'\n\n'
    fig.suptitle(overall_title_general, va='baseline')
    
    # first plot with solve_ivp: position plot 
    ax_a = fig.add_subplot(2,2,1)
    
    # Add an 'x' at the CM of two objects (if using CalcStationaryIC)
    ax_a.plot([0], [0], 'x', c='orange')
    
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1[start : stop], y1[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_a)
    plot_y_vs_x(x2[start : stop], y2[start : stop], 
                color='red',
                label="Object 2",
                ax=ax_a)
    plot_y_vs_x(x3[start : stop], y3[start : stop], 
                axis_labels=x_vs_y_labels, 
                color='green',
                label="Object 3", 
                title=rf'solve_ivp x vs y:$0 \leq t \leq {t_end:.1f}$', 
                ax=ax_a)  
    
    # second plot with solve_ivp: state space plot 
    ax_b = fig.add_subplot(2,2,2)                  
    ax_b.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1_dot[start : stop], y1_dot[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_b)  
    plot_y_vs_x(x2_dot[start : stop], y2_dot[start : stop], 
                color='red',
                label="Object 2",
                ax=ax_b) 
    plot_y_vs_x(x3_dot[start : stop], y3_dot[start : stop], 
                axis_labels=deltax_vs_deltay, 
                color='green',
                label="Object 3", 
                title=rf'solve_ivp xdot vs ydot:$0 \leq t \leq {t_end:.1f}$', 
                ax=ax_b)  
    
    # first plot with Leapfrog: position plot   
    ax_a = fig.add_subplot(2,2,3)                  
    ax_a.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1_2[start : stop], y1_2[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_a) 
    plot_y_vs_x(x2_2[start : stop], y2_2[start : stop], 
                color='red',
                label="Object 2",
                ax=ax_a) 
    plot_y_vs_x(x3_2[start : stop], y3_2[start : stop], 
                axis_labels=x_vs_y_labels, 
                color='green',
                label="Object 3", 
                title=rf'Leapfrog x vs y: $0 \leq t \leq {t_end:.1f}$', 
                ax=ax_a)  
    
    # second plot with Leapfrog: state space plot   
    ax_b = fig.add_subplot(2,2,4)                  
    ax_b.plot([0], [0], 'x', c='orange')
    start, stop = start_stop_indices(t_pts, t_start, t_end)    
    plot_y_vs_x(x1_dot_2[start : stop], y1_dot_2[start : stop], 
                color='blue',
                label="Object 1",
                ax=ax_b)  
    plot_y_vs_x(x2_dot_2[start : stop], y2_dot_2[start : stop], 
                color='red',
                label="Object 2",
                ax=ax_b)  
    plot_y_vs_x(x3_dot_2[start : stop], y3_dot_2[start : stop], 
                axis_labels=deltax_vs_deltay, 
                color='green',
                label="Object 3", 
                title=rf'Leapfrog xdot vs ydot: $0 \leq t \leq {t_end:.1f}$', 
                ax=ax_b)
    
    fig.tight_layout()
    fig.savefig('TripleOrbit.png', bbox_inches='tight')  # always bbox_inches='tight'
    #return fig

# Create the sliders we are interested in
# Physics Parameters
m_1_w = float_widget(value=5., min=0., max=100., step=0.01,
                         description=r'$m_1$:', format='.2f')
m_2_w = float_widget(value=5., min=0., max=100., step=0.01,
                         description=r'$m_2$:', format='.2f')
m_3_w = float_widget(value=5., min=0., max=100., step=0.01,
                         description=r'$m_3$:', format='.2f')
G_val_w = float_widget(value=2., min=0., max=10., step=0.1,
                         description=r'$G$:', format='.1f')
# Position Initial Conditions
x1_0_w = float_widget(value=0., min=-100., max=100., step=0.01,
                         description=r'$x_1(0)$:', format='.2f')
y1_0_w = float_widget(value=5., min=-100., max=100., step=0.01,
                         description=r'$y_1(0)$:', format='.2f')
x2_0_w = float_widget(value=-5.*np.sqrt(3.)/2., min=-100., max=100.,
                step=0.01, description=r'$x_2(0)$:', format='.2f')
y2_0_w = float_widget(value=-5./2, min=-100., max=100., step=0.01,
                         description=r'$y_2(0)$:', format='.2f')
x3_0_w = float_widget(value=5.*np.sqrt(3.)/2., min=-100., max=100.,
                step=0.01, description=r'$x_3(0)$:', format='.2f')
y3_0_w = float_widget(value=-5./2, min=-100., max=100., step=0.01,
                         description=r'$y_3(0)$:', format='.2f')
# Velocity Initial Conditions
x1_dot_0_w = float_widget(value=-1, min=-5., max=5, step=0.01,
                         description=r'$\dot x_1(0)$:', format='.2f')
y1_dot_0_w = float_widget(value=0., min=-5., max=5, step=0.01,
                         description=r'$\dot y_1(0)$:', format='.2f')
x2_dot_0_w = float_widget(value=0.5, min=-5., max=5, step=0.01,
                         description=r'$\dot x_2(0)$:', format='.2f')
y2_dot_0_w = float_widget(value=-np.sqrt(3.)/2., min=-5., max=5, step=0.01,
                         description=r'$\dot y_2(0)$:', format='.2f')
# Time Parameters
delta_t_w = float_widget(value=0.001, min=0.0001, max=0.1, step=0.001,
                         description=r'$\Delta t$:', format='.5f')
t_end_w = float_widget(value=100., min=0., max=200., step=10,
                         description=r'$T_f$:', format='.0f')

# Set up the interactive_output widget 
plot_out = widgets.interactive_output(Plot_TripleOrbit,
                    dict( 
                    m_1=m_1_w,           m_2=m_2_w, 
                    m_3=m_3_w,           G_val=G_val_w,
                    x1_0=x1_0_w,         y1_0=y1_0_w,
                    x2_0=x2_0_w,         y2_0=y2_0_w,
                    x3_0=x3_0_w,         y3_0=y3_0_w,
                    x1_dot_0=x1_dot_0_w, y1_dot_0=y1_dot_0_w,
                    x2_dot_0=x2_dot_0_w, y2_dot_0=y2_dot_0_w,
                    delta_t=delta_t_w,   t_end=t_end_w
                    )
                )
# We want two 
hbox1 = HBox([m_1_w, m_2_w, m_3_w, G_val_w])
hbox2 = HBox([x1_0_w, x2_0_w, x3_0_w])
hbox3 = HBox([y1_0_w, y2_0_w, y3_0_w])
hbox4 = HBox([x1_dot_0_w, x2_dot_0_w])
hbox5 = HBox([y1_dot_0_w, y2_dot_0_w])
hbox6 = HBox([delta_t_w, t_end_w])

tab_height = '70px'  # Fixed minimum height for all tabs. Specify another way?
tab0 = VBox([hbox1, hbox2, hbox3, hbox4, hbox5, hbox6], layout=Layout(min_height=tab_height))
vbox = VBox([tab0, plot_out])

display(vbox)

# %%
# Another Solution:
# Here, obj 2 is fixed in the center while obj's 1, 3 perform orbits
# around obj 2 while always being in a line with all three objects
_ = Plot_TripleOrbit(m_1=5.,                 m_2=5., 
                    m_3=5.,                  G_val=2.,
                    x1_0=-5.,                y1_0=0.,
                    x2_0=0.,                 y2_0=0.,
                    x3_0= 5.,                y3_0=0.,
                    x1_dot_0=0.,             y1_dot_0=-1.,
                    x2_dot_0=0.,             y2_dot_0=0.,
                    delta_t=0.001,           t_end=40)
# Out:
# The orbit may be contained. Total Energy < 0
# Total Energy is: -20.000,

# %%
# Another Solution:
# Here, obj 2 is twice as heavy. It gets permanently coupled 
# to obj 1 while obj 3 gets flung away early on
_ = Plot_TripleOrbit(m_1=5.,                 m_2=10., 
                    m_3=5.,                  G_val=2.,
                    x1_0=0.,                 y1_0=5.,
                    x2_0=-4.33,              y2_0=0.56,
                    x3_0= 4.33,             y3_0=-2.5,
                    x1_dot_0=-1.,             y1_dot_0=0.,
                    x2_dot_0=0.5,             y2_dot_0=-0.87,
                    delta_t=0.01,            t_end=800)
# Out:
# The orbit may be contained. Total Energy < 0
# Total Energy is: -10.113,

# %% [markdown]
# ### Energy Correlation with Orbit?
#
# This time around, objects 1 and 2 can conspire to give significant energy to object 3, resulting in them being more tightly bound, but object 3 escaping the system. Therefore, the total energy is no longer a good measure of how bound the system is. However, if the energy is net negative, we can say at least two objects are bound, and if the energy is net positive, at least one object is unbound. At least this should be the case, however the Leapfrog method in the third set of plots seems to disprove this. More about it below.
#
# ### Orbits we find:
#
# We find some very interesting orbits! The first is the extremely symmetric case, where the three objects are placed on equidistant corners of an equilateral triangle with equal tangential velocities. Here we get a trefoil shape, which can be "tightened" or "loosened" by increasing or decreasing the gravity, respectively. This can be accomplished by modulating G or the masses.
#
# The second orbit I found is the case where the middle object is stationary and the first and third perform elliptical orbits about it, in a way that they are all three on a straight line at any given time. For some reason, increasing the second object's mass seems to break this perfect symmetry. Maybe the system is extremely sensitive to the initial conditions in some way that gets one mass to behave differently than the other for the first timestep, throwing the whole resulting motion out of balance. I am not sure.
#
# The third orbit I found randomly as a case of one object escaping the system momentarily while the other two perform eccentric elliptical orbits around each other.  If you increase the t_end to 1000, you can see that the green object comes back, gets entangled momentarly, and kicks the blue object out for a bit until the blue object rejoins and kicks the green object out again, this time for good. What I find confusing about this orbit is that despite the initial momentum being forced to be zero, all three bodies end up leaving to the top and to the left of the screen on the first plot. So clearly, the solve_ivp differential equation is not conserving momentum. However, if we look at Leapfrog's solution for t_end = 500, it does kick out all three in a way that may conserve momentum. But the fact that all three escape here should still be incorrect, as the total energy is < 0. All kinds of issues exist with my solvers!
