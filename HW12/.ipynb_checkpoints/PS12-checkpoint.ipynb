# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

def CrossSection12(theta_pts):
    c = 5.18*10**(-31)
    return c*( 1. + 6.*np.cos(theta_pts)+9.*(np.cos(theta_pts)**2) )

x_min = 0.
x_max = np.pi
delta_x = 0.01
theta_pts = np.arange(x_min, x_max, delta_x)


fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel(r'$\theta$')
ax.set_ylabel(r'$\frac{d \sigma}{d \Omega}$')
ax.set_title('Differential Cross Section Taylor 14.12')

line, = ax.plot(theta_pts, 
                CrossSection12(theta_pts), 
                color='blue', lw=2)

fig.tight_layout()
fig.savefig('Taylor_Problem_14p12.png', 
                   bbox_inches='tight')

# %%
def ThetavB(b_pts):
    c = 0.5
    R=1.
    return 2*( np.arcsin(b_pts/R) - np.arcsin(c*b_pts / R) )

b_min = 0.
b_max = 1.
delta_b = 0.001
b_pts = np.arange(b_min, b_max, delta_b)


fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel(r'$b$')
ax.set_ylabel(r'$\theta$')
ax.set_title('Theta as Function of B Taylor 14.15')

line, = ax.plot(theta_pts, 
                ThetavB(b_pts), 
                color='blue', lw=2)

fig.tight_layout()
fig.savefig('Taylor_Problem_14p15.png', 
                   bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8384aaf99427> in <module>
#      17
#      18 line, = ax.plot(theta_pts,
# ---> 19                 ThetavB(b_pts),
#      20                 color='blue', lw=2)
#      21
#
# <ipython-input-4-8384aaf99427> in ThetavB(b_pts)
#       2     c = 0.5
#       3     R=1.
# ----> 4     return 2*( np.arcsin(b/R) - np.arcsin(c*b / R) )
#       5
#       6 b_min = 0.
#
# NameError: name 'b' is not defined
